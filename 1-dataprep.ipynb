# %%
import base64
import os
import re
from pathlib import Path
from mistralai import Mistral
from dotenv import load_dotenv

def encode_pdf(pdf_path):
    """Encode the pdf to base64."""
    try:
        with open(pdf_path, "rb") as pdf_file:
            return base64.b64encode(pdf_file.read()).decode('utf-8')
    except FileNotFoundError:
        print(f"Error: The file {pdf_path} was not found.")
        return None
    except Exception as e:
        print(f"Error: {e}")
        return None

def remove_image_references(text):
    """Remove markdown image references like ![img-3.jpeg](img-3.jpeg)"""
    # Pattern to match ![img-X.jpeg](img-X.jpeg) where X is any number
    pattern = r'!\[img-\d+\.jpeg\]\(img-\d+\.jpeg\)'
    cleaned_text = re.sub(pattern, '', text)
    # Remove extra blank lines that might result from removing images
    cleaned_text = re.sub(r'\n{3,}', '\n\n', cleaned_text)
    return cleaned_text

# Load environment variables
load_dotenv()

# Setup
api_key = os.environ["MISTRAL_API_KEY"]
client = Mistral(api_key=api_key)

pdf_folder = Path("pdfs")
output_folder = Path("text-mistral")
output_folder.mkdir(exist_ok=True)

# Process each PDF
for pdf_file in pdf_folder.glob("*.pdf"):
    # Check if output file already exists
    output_file = output_folder / f"{pdf_file.stem}.txt"
    if output_file.exists():
        print(f"Skipping: {pdf_file.name} (already processed)")
        continue
    
    print(f"Processing: {pdf_file.name}")
    
    # Encode PDF to base64
    base64_pdf = encode_pdf(pdf_file)
    if base64_pdf is None:
        continue
    
    # OCR with Mistral
    ocr_response = client.ocr.process(
        model="mistral-ocr-latest",
        document={
            "type": "document_url",
            "document_url": f"data:application/pdf;base64,{base64_pdf}" 
        },
        include_image_base64=True
    )
    
    # Extract markdown text from all pages and concatenate with line breaks
    extracted_text = "\n\n".join([page.markdown for page in ocr_response.pages])
    
    # Remove image references
    cleaned_text = remove_image_references(extracted_text)
    
    # Save extracted text as .txt file
    with open(output_file, "w", encoding="utf-8") as f:
        f.write(cleaned_text)
    
    print(f"✓ Saved to: {output_file.name}")

print("\nDone!")
# Out:
# Skipping: 1) Temel kavramlar önyargı, kalıpyargı ve ayrımcılık.pdf (already processed)
# Skipping: 10) TÜRKİYE’DE ÖRGÜTLENME ÖZGÜRLÜĞÜNÜN GENEL GÖRÜNÜMÜ-II .pdf (already processed)
# Skipping: 11) Yurttaslik_Alani_Bilgi_Notu_1.pdf (already processed)
# Skipping: 12) TERÖRLE MÜCADELEYİ ARAÇSALLAŞTIRMAK.pdf (already processed)
# Skipping: 13) PROTESTO HAKKINI KORU.pdf (already processed)
# Skipping: 14) KomploTeorileri_AR_23.03.23_web.pdf (already processed)
# Skipping: 15) Feminist_Hareketin_Gundemleri_.pdf (already processed)
# Skipping: 16) Sivil Toplum Kuruluşlarının Devlet Tarafından Finansmanı Üzerine Bir Tartışma.pdf (already processed)
# Skipping: 17) Gençlik Politikalarında Karşılaştırmalı Bir Değerlendirme-Türkiye ve Finlandiya Örneği.pdf (already processed)
# Skipping: 18) Avrupa Konseyi Politik Karar Alma Süreçlerine Sivil Katılım Rehberi Çevirisi.pdf (already processed)
# Skipping: 19) Kampüsten Öğrenci Toplulukları .pdf (already processed)
# Skipping: 2) Ayrımcılık ve medya.pdf (already processed)
# Skipping: 20) Gençler Ne(ler) İstiyor_ .pdf (already processed)
# Skipping: 21) Türkiye’de Gençlik ve Siyaset_ Gelecek İçin Nasıl Bir Katılım_ .pdf (already processed)
# Skipping: 22) Gençlik Araştırmaları Dergisi 13.sayı.pdf (already processed)
# Skipping: 23) Türkiye_de Gençlik Miti 1980 Sonrası Türkiye Gençliği İletişim Yayınları.pdf (already processed)
# Skipping: 24) Türkiye’nin Gençliği Araştırması Raporu -SODEV- .pdf (already processed)
# Skipping: 25) Türkiye’de Gençlerin Güvencesizliği_ Çalışma, Geçim ve Yaşam Algısı.pdf (already processed)
# Skipping: 26) Toplumun Boğaziçi Üniversitesi Olaylarına Bakışı.pdf (already processed)
# Skipping: 27) Kürt Gençler’20 Benzerlikler Farklar Değişimler.pdf (already processed)
# Skipping: 28) NEET Gençler Araştırması – NEET Gençlerin İnsan Onuruna Yaraşır Yaşam Sürme Hakkına Erişimi.pdf (already processed)
# Skipping: 29) TGSP Türkiye’nin Gençleri Araştırması.pdf (already processed)
# Skipping: 3) Toplumsal Cinsiyete Dayalı Ayrımcılık.pdf (already processed)
# Skipping: 30) TOG Gençlik Çalışmasının Toplumsal Katılıma Etkisi Araştırması.pdf (already processed)
# Skipping: 31) Türkiye’de Gençlerin İyi Olma Hali Saha Araştırması Bulguları- HABİTAT- .pdf (already processed)
# Skipping: 32) Türkiye Gençlik Araştırması 2021.pdf (already processed)
# Skipping: 33) Türkiye’nin Gençliği Araştırması Raporu -SODEV- 2020.pdf (already processed)
# Skipping: 34)Uluslararası Af Örgütü.pdf (already processed)
# Skipping: 37) Perspectives on Youth Participation.pdf (already processed)
# Skipping: 38) Young people’s right to assemble peacefully.pdf (already processed)
# Skipping: 39) Shrinking democratic civic space for youth.pdf (already processed)
# Skipping: 4) Uluslararası Af Örgütü Raporu 2021-2022 Avrupa ve Orta Asya Değerlendirmesi(sayfa 46-54).pdf (already processed)
# Skipping: 40) Türkiye’de Genç İntiharları.pdf (already processed)
# Skipping: 41) Türkiye’de Genç İntiharları Politika Önerileri.pdf (already processed)
# Skipping: 42) Türkiye_de ifade ve medya özgürlüğü ve insan hakları savunucuları ile sivil toplumun durumu hakkındaki memorandum.pdf (already processed)
# Skipping: 43) Türkiye’deki Gençlik Örgütlerinin İhtiyaç Analizi Raporu 2025.pdf (already processed)
# Skipping: 44)Toplumsal Değerler ve Gençlik Araştırma Raporu.pdf (already processed)
# Skipping: 45) Gençlerin Politik Tercihleri Araştırması.pdf (already processed)
# Skipping: 46)Gençlik Araştırmaları Dergisi 35.sayı.pdf (already processed)
# Skipping: 47)Gençler için nasıl bir kent_.pdf (already processed)
# Skipping: 48) TGSP Gençlerin Gönüllülük Algısı.pdf (already processed)
# Skipping: 49) Yerel Yonetimlere Iliskin PolitikaBelgesi.pdf (already processed)
# Skipping: 5) Paralel Kariyer Arayışının Nedenleri Isparta’da Faaliyet Gösteren STK’larda Bir Araştırma.pdf (already processed)
# Skipping: 50) Milliyetçiliğin Dönüşümü ve Genç Yüzleri.pdf (already processed)
# Skipping: 51)Gençlik Araştırması - Türkiye 2024.pdf (already processed)
# Skipping: 52)CORE Gençlerin Seçimi.pdf (already processed)
# Skipping: 53) Gençlerin Güçlendirilmesine Yönelik Harcamaları İzleme Kılavuzu.pdf (already processed)
# Skipping: 54) Gençlerin Siyasi Katılımı - Şebeke 1.pdf (already processed)
# Skipping: 55) Türkiye_de Gençlerin Katılımı - Şebeke.pdf (already processed)
# Processing: 56) COVID-19 Pandemisi Sürecinde Gençlerin İyilik Halinin Belirlenmesi Araştırması-1-34.pdf
# ✓ Saved to: 56) COVID-19 Pandemisi Sürecinde Gençlerin İyilik Halinin Belirlenmesi Araştırması-1-34.txt
# Processing: 56) COVID-19 Pandemisi Sürecinde Gençlerin İyilik Halinin Belirlenmesi Araştırması-35.pdf
# ✓ Saved to: 56) COVID-19 Pandemisi Sürecinde Gençlerin İyilik Halinin Belirlenmesi Araştırması-1-34.txt
# Processing: 56) COVID-19 Pandemisi Sürecinde Gençlerin İyilik Halinin Belirlenmesi Araştırması-35.pdf
# ✓ Saved to: 56) COVID-19 Pandemisi Sürecinde Gençlerin İyilik Halinin Belirlenmesi Araştırması-35.txt
# Processing: 56) COVID-19 Pandemisi Sürecinde Gençlerin İyilik Halinin Belirlenmesi Araştırması-36-105.pdf
# ✓ Saved to: 56) COVID-19 Pandemisi Sürecinde Gençlerin İyilik Halinin Belirlenmesi Araştırması-35.txt
# Processing: 56) COVID-19 Pandemisi Sürecinde Gençlerin İyilik Halinin Belirlenmesi Araştırması-36-105.pdf
# ✓ Saved to: 56) COVID-19 Pandemisi Sürecinde Gençlerin İyilik Halinin Belirlenmesi Araştırması-36-105.txt
# Skipping: 57) KONDA - Hafıza Merkezi Gençlerin İnsan Hakları Algısı_.pdf (already processed)
# Skipping: 58) Türkiye_de Gençlik Çalışması ve Politikası.pdf (already processed)
# Skipping: 59) LGBTİ gençler gençlik merkezlerinde ne istiyor_.pdf (already processed)
# Skipping: 6) Sivil Toplum Örgütlerinde Profesyonel ve Gönüllü Çalışma İlişkileri Tehditler Ve Fırsatlar.pdf (already processed)
# Skipping: 60) Genç Kadınların Karar Alma Mekanizmalarına Katılımı.pdf (already processed)
# Skipping: 61) Youth Policy Implementation at the Local Level- Imereti and Tbilisi.pdf (already processed)
# Skipping: 62) TGSP Türkiye_nin Gençleri Yurtdışı Algısı.pdf (already processed)
# Skipping: 63) TGSP Türkiye_nin Gençleri Dindarlık Algısı.pdf (already processed)
# Skipping: 64) TGSP Türkiye_nin Gençleri Yükseköğrenim Algısı.pdf (already processed)
# Skipping: 65 ) Türkiye Gençlik Araştırması 2023.pdf (already processed)
# Skipping: 66) SODEV Genclik Arastirmasi Raporu 2021.pdf (already processed)
# Skipping: 67) SERHAT TRA2 Gençlik Araştırması.pdf (already processed)
# Skipping: 68) İPA İstanbulda Gencligin Demografik ve Sosyoekonomik Profili 20 yillik degisim.pdf (already processed)
# Skipping: 69) İPA Üniversite Mezunu Ev Gençleri Araştırması.pdf (already processed)
# Skipping: 7) eşitsiz demokrasiler.pdf (already processed)
# Skipping: 70) IPM Türkiye_de Gençlerin Yurtdışında Yaşama İsteği.pdf (already processed)
# Skipping: 71) İPM Türkiye_de Akıllı Kentleşme ve Gençlik Politikaları.pdf (already processed)
# Skipping: 72) TÜSES Gençlerin Cinsel Sağlık ve Üreme Sağlığı Araştırması.pdf (already processed)
# Skipping: 73) FES Youth Study Southeast Europe .pdf (already processed)
# Skipping: 74) Biarada İstanbul’da Gençlik, Kent Yurttaşlığı ve Yerel Yönetim.pdf (already processed)
# Skipping: 75) Türkiye Gençlik Araştırması Özet Bulgular 2023.pdf (already processed)
# Skipping: 76) Toplum Çalışması Enstitüsü Kim Bu Gençler_.pdf (already processed)
# Skipping: 77) KAOS GL LGBTİ+ Öğrenciler.pdf (already processed)
# Skipping: 78) TOG Üniversiteli Gençlerin İhtiyaçları Araştırması 2024.pdf (already processed)
# Skipping: 79) Haberlerdeki Üniversite 2022.pdf (already processed)
# Skipping: 8) genc-oy-strateji-rapor.pdf (already processed)
# Skipping: 80) TOG Gençlerin İhtiyaçları Araştırması 2022.pdf (already processed)
# Skipping: 81) Yereliz GENÇLİK ALANINDA ÇALIŞAN SİVİL TOPLUM ÖRGÜTLERİ İÇİN YEREL SAVUNUCULUK REHBERİ.pdf (already processed)
# Skipping: 82) KONDA Barometre 2024.pdf (already processed)
# Skipping: 83) OECD Youth Policy Toolkit.pdf (already processed)
# Skipping: 84) TİP_li Öğrenciler Barınma Raporu 2023.pdf (already processed)
# Skipping: 85) ILO Global Employement Trends for Youth 2020.pdf (already processed)
# Skipping: 86) GoFor Hangi Genç_.pdf (already processed)
# Skipping: 87) GoFor 2023 Universiteler icin Uzaktan Egitim ve KYK Yurtlarindan Ogrencilerin Cikarilmasina Iliskin Kararlar Hakkinda Bilgi Notu.pdf (already processed)
# Skipping: 88) Türkiye_de NEET Üzerine Yapılmış Çalışmalara İlişkin Bir Değerlendirme 2024.pdf (already processed)
# Skipping: 89) UNFPA İstatisliklerle Gençlik.pdf (already processed)
# Skipping: 9) Politik Karar Verme Süreçlerine Etkili ve Anlamlı KATILIM HAKKI ve MEKANİZMALAR.pdf (already processed)
# Skipping: 90) FES Genclerin Gözünden Dindar-Seküler Eksenli Kutuplaşma.pdf (already processed)
# Skipping: 91) Veriler.pdf (already processed)
#
# Done!
# ✓ Saved to: 56) COVID-19 Pandemisi Sürecinde Gençlerin İyilik Halinin Belirlenmesi Araştırması-36-105.txt
# Skipping: 57) KONDA - Hafıza Merkezi Gençlerin İnsan Hakları Algısı_.pdf (already processed)
# Skipping: 58) Türkiye_de Gençlik Çalışması ve Politikası.pdf (already processed)
# Skipping: 59) LGBTİ gençler gençlik merkezlerinde ne istiyor_.pdf (already processed)
# Skipping: 6) Sivil Toplum Örgütlerinde Profesyonel ve Gönüllü Çalışma İlişkileri Tehditler Ve Fırsatlar.pdf (already processed)
# Skipping: 60) Genç Kadınların Karar Alma Mekanizmalarına Katılımı.pdf (already processed)
# Skipping: 61) Youth Policy Implementation at the Local Level- Imereti and Tbilisi.pdf (already processed)
# Skipping: 62) TGSP Türkiye_nin Gençleri Yurtdışı Algısı.pdf (already processed)
# Skipping: 63) TGSP Türkiye_nin Gençleri Dindarlık Algısı.pdf (already processed)
# Skipping: 64) TGSP Türkiye_nin Gençleri Yükseköğrenim Algısı.pdf (already processed)
# Skipping: 65 ) Türkiye Gençlik Araştırması 2023.pdf (already processed)
# Skipping: 66) SODEV Genclik Arastirmasi Raporu 2021.pdf (already processed)
# Skipping: 67) SERHAT TRA2 Gençlik Araştırması.pdf (already processed)
# Skipping: 68) İPA İstanbulda Gencligin Demografik ve Sosyoekonomik Profili 20 yillik degisim.pdf (already processed)
# Skipping: 69) İPA Üniversite Mezunu Ev Gençleri Araştırması.pdf (already processed)
# Skipping: 7) eşitsiz demokrasiler.pdf (already processed)
# Skipping: 70) IPM Türkiye_de Gençlerin Yurtdışında Yaşama İsteği.pdf (already processed)
# Skipping: 71) İPM Türkiye_de Akıllı Kentleşme ve Gençlik Politikaları.pdf (already processed)
# Skipping: 72) TÜSES Gençlerin Cinsel Sağlık ve Üreme Sağlığı Araştırması.pdf (already processed)
# Skipping: 73) FES Youth Study Southeast Europe .pdf (already processed)
# Skipping: 74) Biarada İstanbul’da Gençlik, Kent Yurttaşlığı ve Yerel Yönetim.pdf (already processed)
# Skipping: 75) Türkiye Gençlik Araştırması Özet Bulgular 2023.pdf (already processed)
# Skipping: 76) Toplum Çalışması Enstitüsü Kim Bu Gençler_.pdf (already processed)
# Skipping: 77) KAOS GL LGBTİ+ Öğrenciler.pdf (already processed)
# Skipping: 78) TOG Üniversiteli Gençlerin İhtiyaçları Araştırması 2024.pdf (already processed)
# Skipping: 79) Haberlerdeki Üniversite 2022.pdf (already processed)
# Skipping: 8) genc-oy-strateji-rapor.pdf (already processed)
# Skipping: 80) TOG Gençlerin İhtiyaçları Araştırması 2022.pdf (already processed)
# Skipping: 81) Yereliz GENÇLİK ALANINDA ÇALIŞAN SİVİL TOPLUM ÖRGÜTLERİ İÇİN YEREL SAVUNUCULUK REHBERİ.pdf (already processed)
# Skipping: 82) KONDA Barometre 2024.pdf (already processed)
# Skipping: 83) OECD Youth Policy Toolkit.pdf (already processed)
# Skipping: 84) TİP_li Öğrenciler Barınma Raporu 2023.pdf (already processed)
# Skipping: 85) ILO Global Employement Trends for Youth 2020.pdf (already processed)
# Skipping: 86) GoFor Hangi Genç_.pdf (already processed)
# Skipping: 87) GoFor 2023 Universiteler icin Uzaktan Egitim ve KYK Yurtlarindan Ogrencilerin Cikarilmasina Iliskin Kararlar Hakkinda Bilgi Notu.pdf (already processed)
# Skipping: 88) Türkiye_de NEET Üzerine Yapılmış Çalışmalara İlişkin Bir Değerlendirme 2024.pdf (already processed)
# Skipping: 89) UNFPA İstatisliklerle Gençlik.pdf (already processed)
# Skipping: 9) Politik Karar Verme Süreçlerine Etkili ve Anlamlı KATILIM HAKKI ve MEKANİZMALAR.pdf (already processed)
# Skipping: 90) FES Genclerin Gözünden Dindar-Seküler Eksenli Kutuplaşma.pdf (already processed)
# Skipping: 91) Veriler.pdf (already processed)
#
# Done!
